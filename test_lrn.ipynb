# %%
from alexnet.local_response_normalization import LocalReponseNormalization
from data.dataset import get_dataloaders_training

train_loader, _, _ = get_dataloaders_training(batch_size=128, sample_size=1)

LRN = LocalReponseNormalization(n=2)
LRN(next(iter(train_loader))['pixel_values'])
# Out:
# ...
# Loading dataset shards:   0%|          | 0/25 [00:00<?, ?it/s]
# tensor([[[[0.3846, 0.3846, 0.3846,  ..., 0.3450, 0.3427, 0.3450],
#           [0.3893, 0.3893, 0.3870,  ..., 0.3427, 0.3427, 0.3427],
#           [0.3963, 0.3939, 0.3869,  ..., 0.3427, 0.3404, 0.3404],
#           ...,
#           [0.4522, 0.4498, 0.4429,  ..., 0.4312, 0.4335, 0.4429],
#           [0.4522, 0.4475, 0.4475,  ..., 0.4359, 0.4382, 0.4429],
#           [0.4498, 0.4498, 0.4498,  ..., 0.4382, 0.4405, 0.4429]],
#
#          [[0.3846, 0.3846, 0.3846,  ..., 0.3496, 0.3473, 0.3496],
#           [0.3892, 0.3892, 0.3892,  ..., 0.3473, 0.3473, 0.3473],
#           [0.4032, 0.4009, 0.3962,  ..., 0.3473, 0.3450, 0.3450],
#           ...,
#           [0.4497, 0.4474, 0.4404,  ..., 0.4335, 0.4358, 0.4404],
#           [0.4497, 0.4451, 0.4451,  ..., 0.4381, 0.4404, 0.4404],
#           [0.4474, 0.4474, 0.4474,  ..., 0.4404, 0.4428, 0.4404]],
#
#          [[0.3753, 0.3753, 0.3776,  ..., 0.3450, 0.3450, 0.3473],
# ...
